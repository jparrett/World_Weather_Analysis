# %%
# Import the random module.
import random
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),"Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kropotkin
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | vezirkopru
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | eldorado
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | ketchikan
# Processing Record 9 of Set 1 | itacoatiara
# Processing Record 10 of Set 1 | buin
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | dharchula
# Processing Record 14 of Set 1 | okhotsk
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | hambantota
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 1 | mount isa
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | hokitika
# Processing Record 25 of Set 1 | vestmannaeyjar
# Processing Record 26 of Set 1 | ambon
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | umm ruwabah
# City not found. Skipping...
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | norman wells
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | russell
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | paamiut
# Processing Record 39 of Set 1 | nome
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | harper
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | ushumun
# Processing Record 47 of Set 1 | antalaha
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | mogadishu
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | mettur
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | sucua
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | luxor
# Processing Record 10 of Set 2 | abiramam
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | terrace
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | semypolky
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | sarapul
# Processing Record 17 of Set 2 | conde
# Processing Record 18 of Set 2 | orkney
# Processing Record 19 of Set 2 | manjacaze
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | nizhniy odes
# Processing Record 22 of Set 2 | taupo
# Processing Record 23 of Set 2 | tokur
# Processing Record 24 of Set 2 | kharan
# Processing Record 25 of Set 2 | tambopata
# Processing Record 26 of Set 2 | hohoe
# Processing Record 27 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 2 | the valley
# Processing Record 29 of Set 2 | sasd
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | bluff
# Processing Record 34 of Set 2 | leningradskiy
# Processing Record 35 of Set 2 | sfantu gheorghe
# Processing Record 36 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | airai
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | mala
# Processing Record 41 of Set 2 | bilma
# Processing Record 42 of Set 2 | umm lajj
# Processing Record 43 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | scottsbluff
# Processing Record 46 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 47 of Set 2 | winona
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | benguela
# Processing Record 3 of Set 3 | pembroke
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | higuey
# City not found. Skipping...
# Processing Record 6 of Set 3 | svetlyy
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | ko samui
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | zeya
# Processing Record 12 of Set 3 | kaura namoda
# Processing Record 13 of Set 3 | isiolo
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | flinders
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | nioro
# Processing Record 20 of Set 3 | kurya
# Processing Record 21 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 22 of Set 3 | yashalta
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | shieli
# Processing Record 25 of Set 3 | reims
# Processing Record 26 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | pushkino
# Processing Record 29 of Set 3 | rawson
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | save
# Processing Record 32 of Set 3 | camacha
# Processing Record 33 of Set 3 | rudno
# Processing Record 34 of Set 3 | vao
# Processing Record 35 of Set 3 | denpasar
# Processing Record 36 of Set 3 | sikandra rao
# Processing Record 37 of Set 3 | port alfred
# Processing Record 38 of Set 3 | san rafael del sur
# Processing Record 39 of Set 3 | sao jose da coroa grande
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | langarud
# Processing Record 42 of Set 3 | henties bay
# Processing Record 43 of Set 3 | dibaya
# City not found. Skipping...
# Processing Record 44 of Set 3 | taquaritinga do norte
# Processing Record 45 of Set 3 | punta arenas
# Processing Record 46 of Set 3 | porbandar
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 3 | saint-louis
# Processing Record 50 of Set 3 | jeremoabo
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | cidreira
# Processing Record 5 of Set 4 | comodoro rivadavia
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | klaksvik
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | inzer
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | hofn
# Processing Record 13 of Set 4 | ponta do sol
# Processing Record 14 of Set 4 | skibotn
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | mabaruma
# Processing Record 17 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 4 | lebu
# Processing Record 19 of Set 4 | mana
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | penzance
# Processing Record 22 of Set 4 | khandyga
# Processing Record 23 of Set 4 | codrington
# Processing Record 24 of Set 4 | elko
# Processing Record 25 of Set 4 | yar-sale
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | cukai
# Processing Record 28 of Set 4 | novyy urengoy
# Processing Record 29 of Set 4 | half moon bay
# Processing Record 30 of Set 4 | mehamn
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | belaya gora
# Processing Record 33 of Set 4 | rudnaya pristan
# Processing Record 34 of Set 4 | neryungri
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | tautira
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | tsiroanomandidy
# Processing Record 41 of Set 4 | tarpa
# Processing Record 42 of Set 4 | zabol
# Processing Record 43 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | jamestown
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | chokurdakh
# Processing Record 48 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 4 | birjand
# Processing Record 50 of Set 4 | chekhov
# Processing Record 1 of Set 5 | saint-philippe
# Processing Record 2 of Set 5 | ivanovka
# Processing Record 3 of Set 5 | ajdabiya
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | provideniya
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | krasnoselkup
# Processing Record 9 of Set 5 | riyadh
# Processing Record 10 of Set 5 | stykkisholmur
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | port blair
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | znamenskoye
# Processing Record 15 of Set 5 | burica
# City not found. Skipping...
# Processing Record 16 of Set 5 | namatanai
# Processing Record 17 of Set 5 | narsaq
# Processing Record 18 of Set 5 | george
# Processing Record 19 of Set 5 | evensk
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | gat
# Processing Record 22 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 5 | dicabisagan
# Processing Record 25 of Set 5 | thatta
# Processing Record 26 of Set 5 | aripuana
# Processing Record 27 of Set 5 | puerto escondido
# Processing Record 28 of Set 5 | galle
# Processing Record 29 of Set 5 | yeppoon
# Processing Record 30 of Set 5 | rocha
# Processing Record 31 of Set 5 | karpathos
# Processing Record 32 of Set 5 | pavda
# City not found. Skipping...
# Processing Record 33 of Set 5 | ahuimanu
# Processing Record 34 of Set 5 | wanaka
# Processing Record 35 of Set 5 | acapulco
# Processing Record 36 of Set 5 | locri
# Processing Record 37 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 38 of Set 5 | calama
# Processing Record 39 of Set 5 | qingdao
# Processing Record 40 of Set 5 | grand gaube
# Processing Record 41 of Set 5 | yizheng
# Processing Record 42 of Set 5 | poso
# Processing Record 43 of Set 5 | san felipe
# Processing Record 44 of Set 5 | oranjemund
# Processing Record 45 of Set 5 | marawi
# Processing Record 46 of Set 5 | velsk
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | laguna
# Processing Record 49 of Set 5 | beroroha
# Processing Record 50 of Set 5 | pangnirtung
# Processing Record 1 of Set 6 | beringovskiy
# Processing Record 2 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 6 | westport
# Processing Record 4 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 6 | varhaug
# Processing Record 6 of Set 6 | port elizabeth
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | killybegs
# Processing Record 9 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 6 | alice springs
# Processing Record 12 of Set 6 | puerto madryn
# Processing Record 13 of Set 6 | armidale
# Processing Record 14 of Set 6 | kampong thum
# Processing Record 15 of Set 6 | berlevag
# Processing Record 16 of Set 6 | katsuura
# Processing Record 17 of Set 6 | ribeira grande
# Processing Record 18 of Set 6 | bay roberts
# Processing Record 19 of Set 6 | nouadhibou
# Processing Record 20 of Set 6 | micheweni
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | san lazaro
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | selma
# Processing Record 25 of Set 6 | ulladulla
# Processing Record 26 of Set 6 | bonavista
# Processing Record 27 of Set 6 | oyotun
# Processing Record 28 of Set 6 | masunga
# Processing Record 29 of Set 6 | khawhai
# Processing Record 30 of Set 6 | nipawin
# Processing Record 31 of Set 6 | marsta
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | ushtobe
# Processing Record 34 of Set 6 | datong
# Processing Record 35 of Set 6 | portland
# Processing Record 36 of Set 6 | port-gentil
# Processing Record 37 of Set 6 | hobyo
# Processing Record 38 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 39 of Set 6 | kozhva
# Processing Record 40 of Set 6 | makakilo city
# Processing Record 41 of Set 6 | puerto del rosario
# Processing Record 42 of Set 6 | bereda
# Processing Record 43 of Set 6 | polewali
# Processing Record 44 of Set 6 | severo-kurilsk
# Processing Record 45 of Set 6 | diamantino
# Processing Record 46 of Set 6 | hervey bay
# Processing Record 47 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 6 | copiapo
# Processing Record 49 of Set 6 | marsa matruh
# Processing Record 50 of Set 6 | el espino de santa rosa
# Processing Record 1 of Set 7 | whitehorse
# Processing Record 2 of Set 7 | lima
# Processing Record 3 of Set 7 | itupiranga
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | kargil
# Processing Record 6 of Set 7 | safaga
# Processing Record 7 of Set 7 | havre-saint-pierre
# Processing Record 8 of Set 7 | coihaique
# Processing Record 9 of Set 7 | staryy nadym
# Processing Record 10 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 7 | lamesa
# Processing Record 12 of Set 7 | yatou
# Processing Record 13 of Set 7 | ratodero
# Processing Record 14 of Set 7 | touros
# Processing Record 15 of Set 7 | zapolyarnyy
# Processing Record 16 of Set 7 | wadi musa
# Processing Record 17 of Set 7 | bria
# Processing Record 18 of Set 7 | manavgat
# Processing Record 19 of Set 7 | bichura
# Processing Record 20 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 21 of Set 7 | pagman
# City not found. Skipping...
# Processing Record 22 of Set 7 | alta floresta
# Processing Record 23 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 7 | tambura
# Processing Record 28 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | kalanguy
# Processing Record 31 of Set 7 | flin flon
# Processing Record 32 of Set 7 | beloha
# Processing Record 33 of Set 7 | pozzallo
# Processing Record 34 of Set 7 | dosso
# Processing Record 35 of Set 7 | khor
# Processing Record 36 of Set 7 | gravdal
# Processing Record 37 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 7 | vallenar
# Processing Record 39 of Set 7 | hirara
# Processing Record 40 of Set 7 | bulgan
# Processing Record 41 of Set 7 | tura
# Processing Record 42 of Set 7 | rondonopolis
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | constitucion
# Processing Record 45 of Set 7 | necochea
# Processing Record 46 of Set 7 | krasnaya gorbatka
# Processing Record 47 of Set 7 | castro
# Processing Record 48 of Set 7 | bandarbeyla
# Processing Record 49 of Set 7 | elat
# Processing Record 50 of Set 7 | itarema
# Processing Record 1 of Set 8 | rio grande
# Processing Record 2 of Set 8 | aksarka
# Processing Record 3 of Set 8 | port shepstone
# Processing Record 4 of Set 8 | altay
# Processing Record 5 of Set 8 | brae
# Processing Record 6 of Set 8 | mitsamiouli
# Processing Record 7 of Set 8 | kristianstad
# Processing Record 8 of Set 8 | opuwo
# Processing Record 9 of Set 8 | eenhana
# Processing Record 10 of Set 8 | santa cruz
# Processing Record 11 of Set 8 | shelburne
# Processing Record 12 of Set 8 | soyo
# Processing Record 13 of Set 8 | jaciara
# Processing Record 14 of Set 8 | hwange
# Processing Record 15 of Set 8 | kantabanji
# Processing Record 16 of Set 8 | gemena
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | nadym
# Processing Record 19 of Set 8 | oussouye
# Processing Record 20 of Set 8 | tena
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | kenitra
# Processing Record 23 of Set 8 | roatan
# Processing Record 24 of Set 8 | fukue
# Processing Record 25 of Set 8 | vung tau
# Processing Record 26 of Set 8 | praia da vitoria
# Processing Record 27 of Set 8 | belmonte
# Processing Record 28 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | mbandaka
# Processing Record 31 of Set 8 | marsh harbour
# Processing Record 32 of Set 8 | brigantine
# Processing Record 33 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 8 | guilin
# Processing Record 35 of Set 8 | nassau
# Processing Record 36 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 37 of Set 8 | san quintin
# Processing Record 38 of Set 8 | ashland
# Processing Record 39 of Set 8 | mapimi
# Processing Record 40 of Set 8 | fare
# Processing Record 41 of Set 8 | tiruchchendur
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | leua
# Processing Record 44 of Set 8 | strezhevoy
# Processing Record 45 of Set 8 | chapais
# Processing Record 46 of Set 8 | joniskis
# Processing Record 47 of Set 8 | guayaramerin
# Processing Record 48 of Set 8 | dargaville
# Processing Record 49 of Set 8 | le port
# Processing Record 50 of Set 8 | goderich
# Processing Record 1 of Set 9 | labuhan
# Processing Record 2 of Set 9 | verkhnevilyuysk
# Processing Record 3 of Set 9 | senanga
# Processing Record 4 of Set 9 | athabasca
# Processing Record 5 of Set 9 | orocue
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | makokou
# Processing Record 8 of Set 9 | prince rupert
# Processing Record 9 of Set 9 | loandjili
# Processing Record 10 of Set 9 | vila franca do campo
# Processing Record 11 of Set 9 | bo phloi
# Processing Record 12 of Set 9 | soe
# Processing Record 13 of Set 9 | saint george
# Processing Record 14 of Set 9 | bonaventure
# Processing Record 15 of Set 9 | severnoye
# Processing Record 16 of Set 9 | igarapava
# Processing Record 17 of Set 9 | melilla
# Processing Record 18 of Set 9 | humaita
# Processing Record 19 of Set 9 | olinda
# Processing Record 20 of Set 9 | tarata
# Processing Record 21 of Set 9 | derzhavinsk
# Processing Record 22 of Set 9 | luanda
# Processing Record 23 of Set 9 | luoyang
# Processing Record 24 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 9 | amuntai
# Processing Record 26 of Set 9 | union
# Processing Record 27 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | shenkursk
# Processing Record 29 of Set 9 | chipinge
# Processing Record 30 of Set 9 | dalinghe
# City not found. Skipping...
# Processing Record 31 of Set 9 | boca do acre
# Processing Record 32 of Set 9 | maryville
# Processing Record 33 of Set 9 | chichi
# Processing Record 34 of Set 9 | wajir
# Processing Record 35 of Set 9 | yeniseysk
# Processing Record 36 of Set 9 | zhezkazgan
# Processing Record 37 of Set 9 | clyde river
# Processing Record 38 of Set 9 | coquimbo
# Processing Record 39 of Set 9 | onverwacht
# Processing Record 40 of Set 9 | agva
# City not found. Skipping...
# Processing Record 41 of Set 9 | belyy yar
# Processing Record 42 of Set 9 | bubaque
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | myskhako
# Processing Record 45 of Set 9 | bengkulu
# Processing Record 46 of Set 9 | basco
# Processing Record 47 of Set 9 | geraldton
# Processing Record 48 of Set 9 | weiser
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | cody
# Processing Record 1 of Set 10 | faya
# Processing Record 2 of Set 10 | aguilas
# Processing Record 3 of Set 10 | chanika
# Processing Record 4 of Set 10 | lewistown
# Processing Record 5 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 6 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 10 | mantua
# Processing Record 8 of Set 10 | aluksne
# Processing Record 9 of Set 10 | lenger
# Processing Record 10 of Set 10 | simpang
# Processing Record 11 of Set 10 | mackay
# Processing Record 12 of Set 10 | port-cartier
# Processing Record 13 of Set 10 | jardim
# Processing Record 14 of Set 10 | isangel
# Processing Record 15 of Set 10 | san vicente
# Processing Record 16 of Set 10 | madan
# Processing Record 17 of Set 10 | samur
# Processing Record 18 of Set 10 | hovd
# Processing Record 19 of Set 10 | conceicao do araguaia
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | baturaja
# Processing Record 22 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 10 | barcelona
# Processing Record 24 of Set 10 | hami
# Processing Record 25 of Set 10 | amherst center
# Processing Record 26 of Set 10 | cururupu
# Processing Record 27 of Set 10 | matagami
# Processing Record 28 of Set 10 | bytosh
# Processing Record 29 of Set 10 | tabas
# Processing Record 30 of Set 10 | charsadda
# Processing Record 31 of Set 10 | kutum
# Processing Record 32 of Set 10 | kruisfontein
# Processing Record 33 of Set 10 | srednekolymsk
# Processing Record 34 of Set 10 | kieta
# Processing Record 35 of Set 10 | sinop
# Processing Record 36 of Set 10 | atakpame
# Processing Record 37 of Set 10 | chicama
# Processing Record 38 of Set 10 | bilibino
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 10 | salalah
# Processing Record 42 of Set 10 | mumford
# Processing Record 43 of Set 10 | lar
# Processing Record 44 of Set 10 | esil
# Processing Record 45 of Set 10 | nyrob
# Processing Record 46 of Set 10 | goalpara
# Processing Record 47 of Set 10 | dhali
# Processing Record 48 of Set 10 | buala
# Processing Record 49 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 10 | huarmey
# Processing Record 1 of Set 11 | plouzane
# Processing Record 2 of Set 11 | zlobin
# Processing Record 3 of Set 11 | shimoda
# Processing Record 4 of Set 11 | terme
# Processing Record 5 of Set 11 | quatre cocos
# Processing Record 6 of Set 11 | la romana
# Processing Record 7 of Set 11 | taunggyi
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | zaokskiy
# Processing Record 10 of Set 11 | port hedland
# Processing Record 11 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 11 | barquisimeto
# Processing Record 13 of Set 11 | berbera
# Processing Record 14 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 11 | mao
# Processing Record 16 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 17 of Set 11 | bobonong
# City not found. Skipping...
# Processing Record 18 of Set 11 | mecca
# Processing Record 19 of Set 11 | black river
# Processing Record 20 of Set 11 | celestun
# Processing Record 21 of Set 11 | vicosa do ceara
# Processing Record 22 of Set 11 | anadyr
# Processing Record 23 of Set 11 | auki
# Processing Record 24 of Set 11 | general pico
# Processing Record 25 of Set 11 | atikokan
# Processing Record 26 of Set 11 | ankazobe
# Processing Record 27 of Set 11 | fortuna
# Processing Record 28 of Set 11 | lixourion
# Processing Record 29 of Set 11 | ancud
# Processing Record 30 of Set 11 | norwich
# Processing Record 31 of Set 11 | saint-pierre
# Processing Record 32 of Set 11 | caronport
# Processing Record 33 of Set 11 | sioux lookout
# Processing Record 34 of Set 11 | axim
# Processing Record 35 of Set 11 | yarada
# Processing Record 36 of Set 11 | la libertad
# Processing Record 37 of Set 11 | turayf
# Processing Record 38 of Set 11 | pantai remis
# Processing Record 39 of Set 11 | sampit
# Processing Record 40 of Set 11 | lingdong
# Processing Record 41 of Set 11 | mareeba
# Processing Record 42 of Set 11 | pochutla
# Processing Record 43 of Set 11 | bafoulabe
# Processing Record 44 of Set 11 | hamilton
# Processing Record 45 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 11 | baoqing
# Processing Record 47 of Set 11 | whitianga
# Processing Record 48 of Set 11 | storsteinnes
# Processing Record 49 of Set 11 | ukiah
# Processing Record 50 of Set 11 | morant bay
# Processing Record 1 of Set 12 | dunedin
# Processing Record 2 of Set 12 | neuquen
# Processing Record 3 of Set 12 | los llanos de aridane
# Processing Record 4 of Set 12 | san lawrenz
# Processing Record 5 of Set 12 | san cristobal
# Processing Record 6 of Set 12 | torbay
# Processing Record 7 of Set 12 | berani
# Processing Record 8 of Set 12 | hailin
# Processing Record 9 of Set 12 | payson
# Processing Record 10 of Set 12 | laukaa
# Processing Record 11 of Set 12 | curtea
# Processing Record 12 of Set 12 | poya
# Processing Record 13 of Set 12 | ambalavao
# Processing Record 14 of Set 12 | hualmay
# Processing Record 15 of Set 12 | faridpur
# Processing Record 16 of Set 12 | vila velha
# Processing Record 17 of Set 12 | moose factory
# Processing Record 18 of Set 12 | hosakote
# Processing Record 19 of Set 12 | luwuk
# Processing Record 20 of Set 12 | hammerfest
# Processing Record 21 of Set 12 | imeni poliny osipenko
# Processing Record 22 of Set 12 | ust-maya
# Processing Record 23 of Set 12 | januaria
# Processing Record 24 of Set 12 | batagay-alyta
# Processing Record 25 of Set 12 | florianopolis
# Processing Record 26 of Set 12 | coihueco
# Processing Record 27 of Set 12 | nurota
# Processing Record 28 of Set 12 | usinsk
# Processing Record 29 of Set 12 | braganca
# Processing Record 30 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 12 | cherskiy
# Processing Record 32 of Set 12 | casa nova
# Processing Record 33 of Set 12 | shingu
# Processing Record 34 of Set 12 | trelew
# Processing Record 35 of Set 12 | meulaboh
# Processing Record 36 of Set 12 | kovylkino
# Processing Record 37 of Set 12 | ewa beach
# Processing Record 38 of Set 12 | haines junction
# Processing Record 39 of Set 12 | razole
# Processing Record 40 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 12 | great falls
# Processing Record 43 of Set 12 | zaria
# Processing Record 44 of Set 12 | noyabrsk
# Processing Record 45 of Set 12 | kearney
# Processing Record 46 of Set 12 | esso
# Processing Record 47 of Set 12 | kabalo
# Processing Record 48 of Set 12 | kupang
# Processing Record 49 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 12 | marrakesh
# Processing Record 1 of Set 13 | alamogordo
# Processing Record 2 of Set 13 | bauta
# Processing Record 3 of Set 13 | balkanabat
# Processing Record 4 of Set 13 | tayshet
# Processing Record 5 of Set 13 | nyurba
# Processing Record 6 of Set 13 | boende
# Processing Record 7 of Set 13 | ballangen
# Processing Record 8 of Set 13 | livingston
# Processing Record 9 of Set 13 | abastumani
# Processing Record 10 of Set 13 | amarante do maranhao
# Processing Record 11 of Set 13 | illapel
# Processing Record 12 of Set 13 | tambovka
# Processing Record 13 of Set 13 | inhambane
# Processing Record 14 of Set 13 | karratha
# Processing Record 15 of Set 13 | prata
# Processing Record 16 of Set 13 | severodvinsk
# Processing Record 17 of Set 13 | progreso
# Processing Record 18 of Set 13 | divo
# Processing Record 19 of Set 13 | ankang
# Processing Record 20 of Set 13 | piacabucu
# Processing Record 21 of Set 13 | bonney lake
# Processing Record 22 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 23 of Set 13 | yulin
# Processing Record 24 of Set 13 | guerrero negro
# Processing Record 25 of Set 13 | hornepayne
# Processing Record 26 of Set 13 | maindargi
# Processing Record 27 of Set 13 | xingcheng
# Processing Record 28 of Set 13 | teya
# Processing Record 29 of Set 13 | manali
# Processing Record 30 of Set 13 | egvekinot
# Processing Record 31 of Set 13 | waipawa
# Processing Record 32 of Set 13 | lompoc
# Processing Record 33 of Set 13 | kailua
# Processing Record 34 of Set 13 | morogoro
# Processing Record 35 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 36 of Set 13 | sechenovo
# Processing Record 37 of Set 13 | coahuayana
# Processing Record 38 of Set 13 | muros
# Processing Record 39 of Set 13 | lasa
# Processing Record 40 of Set 13 | entre rios
# Processing Record 41 of Set 13 | vanavara
# Processing Record 42 of Set 13 | porto novo
# Processing Record 43 of Set 13 | ust-ishim
# Processing Record 44 of Set 13 | freeport
# Processing Record 45 of Set 13 | cicarlau
# City not found. Skipping...
# Processing Record 46 of Set 13 | fereydun kenar
# Processing Record 47 of Set 13 | dhidhdhoo
# Processing Record 48 of Set 13 | korla
# Processing Record 49 of Set 13 | xihe
# Processing Record 50 of Set 13 | san andres
# Processing Record 1 of Set 14 | boguchany
# Processing Record 2 of Set 14 | williams lake
# Processing Record 3 of Set 14 | francisco sa
# Processing Record 4 of Set 14 | sabang
# Processing Record 5 of Set 14 | umm kaddadah
# Processing Record 6 of Set 14 | fairbanks
# Processing Record 7 of Set 14 | khorixas
# Processing Record 8 of Set 14 | northam
# Processing Record 9 of Set 14 | padang
# Processing Record 10 of Set 14 | deputatskiy
# Processing Record 11 of Set 14 | jumla
# Processing Record 12 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 13 of Set 14 | kununurra
# Processing Record 14 of Set 14 | kenai
# Processing Record 15 of Set 14 | ishigaki
# Processing Record 16 of Set 14 | fort-shevchenko
# Processing Record 17 of Set 14 | eidsvoll
# Processing Record 18 of Set 14 | siilinjarvi
# Processing Record 19 of Set 14 | dwarka
# Processing Record 20 of Set 14 | goure
# Processing Record 21 of Set 14 | shar
# Processing Record 22 of Set 14 | chicontepec
# Processing Record 23 of Set 14 | shenjiamen
# Processing Record 24 of Set 14 | chaupal
# Processing Record 25 of Set 14 | tessalit
# Processing Record 26 of Set 14 | waddan
# Processing Record 27 of Set 14 | magadi
# Processing Record 28 of Set 14 | kassala
# Processing Record 29 of Set 14 | anamur
# Processing Record 30 of Set 14 | angoram
# Processing Record 31 of Set 14 | humble
# Processing Record 32 of Set 14 | lakes entrance
# Processing Record 33 of Set 14 | sabzevar
# Processing Record 34 of Set 14 | puqi
# Processing Record 35 of Set 14 | bose
# Processing Record 36 of Set 14 | mihai bravu
# Processing Record 37 of Set 14 | tyup
# Processing Record 38 of Set 14 | corowa
# Processing Record 39 of Set 14 | odweyne
# Processing Record 40 of Set 14 | saldanha
# Processing Record 41 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 14 | zhireken
# Processing Record 43 of Set 14 | santa maria
# Processing Record 44 of Set 14 | keti bandar
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | sept-iles
# Processing Record 47 of Set 14 | vanderhoof
# Processing Record 48 of Set 14 | tabou
# Processing Record 49 of Set 14 | shima
# Processing Record 50 of Set 14 | baripada
# Processing Record 1 of Set 15 | balsas
# Processing Record 2 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 15 | emerald
# Processing Record 4 of Set 15 | kudahuvadhoo
# Processing Record 5 of Set 15 | palencia
# Processing Record 6 of Set 15 | tukrah
# Processing Record 7 of Set 15 | santiago del estero
# Processing Record 8 of Set 15 | sakti
# Processing Record 9 of Set 15 | kuytun
# Processing Record 10 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 15 | sao filipe
# Processing Record 12 of Set 15 | pijijiapan
# Processing Record 13 of Set 15 | xuddur
# Processing Record 14 of Set 15 | hanyang
# Processing Record 15 of Set 15 | phangnga
# Processing Record 16 of Set 15 | raudeberg
# Processing Record 17 of Set 15 | svarychiv
# Processing Record 18 of Set 15 | serenje
# Processing Record 19 of Set 15 | diveyevo
# Processing Record 20 of Set 15 | kloulklubed
# Processing Record 21 of Set 15 | kaeo
# Processing Record 22 of Set 15 | vestmanna
# Processing Record 23 of Set 15 | chernyshevskiy
# Processing Record 24 of Set 15 | chapleau
# Processing Record 25 of Set 15 | manicore
# Processing Record 26 of Set 15 | nanortalik
# Processing Record 27 of Set 15 | talakan
# Processing Record 28 of Set 15 | boa esperanca
# Processing Record 29 of Set 15 | samana
# Processing Record 30 of Set 15 | kandrian
# Processing Record 31 of Set 15 | finschhafen
# Processing Record 32 of Set 15 | chase
# Processing Record 33 of Set 15 | mwanza
# Processing Record 34 of Set 15 | nova olimpia
# Processing Record 35 of Set 15 | putina
# Processing Record 36 of Set 15 | ihosy
# Processing Record 37 of Set 15 | sinnamary
# Processing Record 38 of Set 15 | oakdale
# Processing Record 39 of Set 15 | okha
# Processing Record 40 of Set 15 | la estancia
# Processing Record 41 of Set 15 | changli
# Processing Record 42 of Set 15 | mianwali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kropotkin      RU  45.4375   40.5756     35.01        88         100
# 1       Albany      US  42.6001  -73.9662     66.99        18          74
# 2  New Norfolk      AU -42.7826  147.0587     64.00        79         100
# 3   Vezirkopru      TR  41.1436   35.4547     37.40        75          75
# 4     Tasiilaq      GL  65.6145  -37.6368     12.20        67           0
# 5     Eldorado      BR -23.7869  -54.2836     81.97        73          93
# 6    Saskylakh      RU  71.9167  114.0833    -40.02       100          70
# 7    Ketchikan      US  55.3422 -131.6461     42.80       100          90
# 8  Itacoatiara      BR  -3.1431  -58.4442     82.22        81          54
# 9         Buin      CL -33.7333  -70.7500     78.80        36           0
#
#    Wind Speed Current Description
# 0       10.38                snow
# 1        3.00       broken clouds
# 2        1.01     overcast clouds
# 3       12.66          light rain
# 4        2.30           clear sky
# 5        3.83     overcast clouds
# 6        5.68       broken clouds
# 7       12.66       moderate rain
# 8        2.48       broken clouds
# 9        9.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
